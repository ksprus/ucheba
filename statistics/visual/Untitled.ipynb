# %% [markdown]
# # Домашнее задание к лекции "Визуализация данных"

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data=pd.read_csv('country_wise_latest.csv')
datas=data.loc[7:12,['Country/Region','Confirmed',  'Deaths', 'Recovered']]
datas=datas[['Country/Region','Confirmed',  'Deaths', 'Recovered']].groupby('Country/Region').sum()
datas['Recovered'].plot(kind='pie',title='Статистика выздоровевших по странам',ylabel='',autopct='%1.0f%%', colors = ['#14FA52', '#6283FA', '#12DEAF','#61E7FA', '#CA84FA', '#E0CB2B' ] )
# Out:
# <AxesSubplot:title={'center':'Статистика выздоровевших по странам'}>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data=pd.read_csv('country_wise_latest.csv')
datas=data.loc[:10,['Country/Region','Confirmed',  'Deaths', 'Recovered']]
datas=datas[['Country/Region','Confirmed',  'Deaths', 'Recovered']].groupby('Country/Region').sum()
datas['Deaths'].plot(kind='area',title='Смертность',xlabel='',ylabel='Кол-во человек', color='#484848')
# Out:
# <AxesSubplot:title={'center':'Смертность'}, ylabel='Кол-во человек'>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data=pd.read_csv('country_wise_latest.csv')
datas=data.iloc[40:49,[0,6,7]]
datas=datas[['Country/Region','New deaths',  'New recovered']].groupby('Country/Region').sum()
datas=datas.rename(columns={'New deaths':'Смерти',  'New recovered':'Выздоровления'})
datas.plot(kind='bar',title='Соотношение новых случаев смерти и выздоровления',xlabel='',ylabel='Кол-во человек', color={"Смерти": "red", "Выздоровления": "#31E752"})
# Out:
# <AxesSubplot:title={'center':'Соотношение новых случаев смерти и выздоровления'}, ylabel='Кол-во человек'>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data=pd.read_csv('country_wise_latest.csv')
datas=data.loc[1:10,['Country/Region','Confirmed',  'Deaths', 'Recovered']]
datas=datas[['Country/Region','Confirmed']].groupby('Country/Region').sum().sort_values('Confirmed',ascending=False)

datas.style.bar(align='mid', color='#22E0D4')
# Out:
# <style  type="text/css" >
# #T_faa02590_e27f_11eb_ae6c_68b599665a33row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#22E0D4 100.0%, transparent 100.0%);
#         }#T_faa02590_e27f_11eb_ae6c_68b599665a33row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#22E0D4 22.3%, transparent 22.3%);
#         }#T_faa02590_e27f_11eb_ae6c_68b599665a33row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#22E0D4 18.2%, transparent 18.2%);
#         }#T_faa02590_e27f_11eb_ae6c_68b599665a33row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#22E0D4 16.7%, transparent 16.7%);
#         }#T_faa02590_e27f_11eb_ae6c_68b599665a33row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#22E0D4 12.3%, transparent 12.3%);
#         }#T_faa02590_e27f_11eb_ae6c_68b599665a33row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#22E0D4 9.1%, transparent 9.1%);
#         }#T_faa02590_e27f_11eb_ae6c_68b599665a33row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#22E0D4 2.9%, transparent 2.9%);
#         }#T_faa02590_e27f_11eb_ae6c_68b599665a33row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#22E0D4 0.6%, transparent 0.6%);
#         }#T_faa02590_e27f_11eb_ae6c_68b599665a33row8_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#22E0D4 0.5%, transparent 0.5%);
#         }#T_faa02590_e27f_11eb_ae6c_68b599665a33row9_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#22E0D4 0.1%, transparent 0.1%);
#         }</style><table id="T_faa02590_e27f_11eb_ae6c_68b599665a33" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Confirmed</th>    </tr>    <tr>        <th class="index_name level0" >Country/Region</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_faa02590_e27f_11eb_ae6c_68b599665a33level0_row0" class="row_heading level0 row0" >Argentina</th>
#                         <td id="T_faa02590_e27f_11eb_ae6c_68b599665a33row0_col0" class="data row0 col0" >167416</td>
#             </tr>
#             <tr>
#                         <th id="T_faa02590_e27f_11eb_ae6c_68b599665a33level0_row1" class="row_heading level0 row1" >Armenia</th>
#                         <td id="T_faa02590_e27f_11eb_ae6c_68b599665a33row1_col0" class="data row1 col0" >37390</td>
#             </tr>
#             <tr>
#                         <th id="T_faa02590_e27f_11eb_ae6c_68b599665a33level0_row2" class="row_heading level0 row2" >Azerbaijan</th>
#                         <td id="T_faa02590_e27f_11eb_ae6c_68b599665a33row2_col0" class="data row2 col0" >30446</td>
#             </tr>
#             <tr>
#                         <th id="T_faa02590_e27f_11eb_ae6c_68b599665a33level0_row3" class="row_heading level0 row3" >Algeria</th>
#                         <td id="T_faa02590_e27f_11eb_ae6c_68b599665a33row3_col0" class="data row3 col0" >27973</td>
#             </tr>
#             <tr>
#                         <th id="T_faa02590_e27f_11eb_ae6c_68b599665a33level0_row4" class="row_heading level0 row4" >Austria</th>
#                         <td id="T_faa02590_e27f_11eb_ae6c_68b599665a33row4_col0" class="data row4 col0" >20558</td>
#             </tr>
#             <tr>
#                         <th id="T_faa02590_e27f_11eb_ae6c_68b599665a33level0_row5" class="row_heading level0 row5" >Australia</th>
#                         <td id="T_faa02590_e27f_11eb_ae6c_68b599665a33row5_col0" class="data row5 col0" >15303</td>
#             </tr>
#             <tr>
#                         <th id="T_faa02590_e27f_11eb_ae6c_68b599665a33level0_row6" class="row_heading level0 row6" >Albania</th>
#                         <td id="T_faa02590_e27f_11eb_ae6c_68b599665a33row6_col0" class="data row6 col0" >4880</td>
#             </tr>
#             <tr>
#                         <th id="T_faa02590_e27f_11eb_ae6c_68b599665a33level0_row7" class="row_heading level0 row7" >Angola</th>
#                         <td id="T_faa02590_e27f_11eb_ae6c_68b599665a33row7_col0" class="data row7 col0" >950</td>
#             </tr>
#             <tr>
#                         <th id="T_faa02590_e27f_11eb_ae6c_68b599665a33level0_row8" class="row_heading level0 row8" >Andorra</th>
#                         <td id="T_faa02590_e27f_11eb_ae6c_68b599665a33row8_col0" class="data row8 col0" >907</td>
#             </tr>
#             <tr>
#                         <th id="T_faa02590_e27f_11eb_ae6c_68b599665a33level0_row9" class="row_heading level0 row9" >Antigua and Barbuda</th>
#                         <td id="T_faa02590_e27f_11eb_ae6c_68b599665a33row9_col0" class="data row9 col0" >86</td>
#             </tr>
#     </tbody></table>
